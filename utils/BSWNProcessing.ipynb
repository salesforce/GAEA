# %%
import pandas as pd
import os

# %%
data_dir = '../data/BWSN'
df = pd.read_csv(os.path.join(data_dir,'edges.tsv'), sep='\t',index_col=False)

# %%
df
# Out:
#                 ID           Node1           Node2       Length   Diameter  \
# 0           LINK-0      JUNCTION-0   JUNCTION-3682   242.200000   6.000000
# 1           LINK-1   JUNCTION-3130   JUNCTION-3238   618.400000   8.000000
# 2           LINK-2  JUNCTION-12389   JUNCTION-1718   439.200000  12.000000
# 3           LINK-3   JUNCTION-1691   JUNCTION-1704   410.400000   6.000000
# 4           LINK-4  JUNCTION-11726  JUNCTION-11642   578.700000   6.000000
# 5           LINK-5  JUNCTION-11725  JUNCTION-11744    35.400000   8.000000
# 6           LINK-6  JUNCTION-11643  JUNCTION-11770   157.600000   2.000000
# 7           LINK-7  JUNCTION-11736  JUNCTION-11726   543.200000   8.000000
# 8           LINK-8  JUNCTION-11732  JUNCTION-11484   440.700000   8.000000
# 9           LINK-9  JUNCTION-11736  JUNCTION-11486    71.000000   8.000000
# 10         LINK-10  JUNCTION-11486  JUNCTION-11758   323.200000   8.000000
# ...
